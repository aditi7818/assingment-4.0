# %%
Question: Explain class and object with respect to object-oriented Programming.Give a suitable example.
Answer: 
class of object-oriented programming:
A class is a user-defined blueprint of an object that describes what a specific kind of object will look like. A class description consists
of two things:
attributes, and Implementations of behaviour.
For Example, a mobile phone has attribute like a brand name, RAM, and functions like texting and calling. Thus, the mobile phone is a class of various phones
(the objects).

What is an object?
an object is a single instance of a class, which contains data and methods working on that data. so an object consists of three things:
    Name: This is a variable name that repersents the object.
    Member data: The data that describes the object.
    Member methods: Behavior that describes the object. 
For example, Samsung galaxy is an object with the brand name samsung, 2GB RAM sa properties, and calling and texting as behaviours.

# %%
Question: Name the four pillars of Oops.
Answer: There are four pillars of oops:
    1.) Encapsulation
    2.) Inheritance
    3.) Polymorphism
    4.) Abstaction

# %%
Question: Explain why the _ _init_ _() fuction is used. give a suitable example.
Answer: _ _ init_ _ is a special python method that runs whenever a new object is created. these types of functions are used to initialize
the attributes of that class, E.g., if the class is person, then the attributes will be name, age, etc.
Example: 
class person:
    def__init__(self, name, age):
        self.name= name
        self.age= age
p1 = Person("jhon","age")
print(p1.name)
print(p1.age)

# %%
Question: Why self is used in OOPs?
Answer: SELF repersents the instance of class. this handy keyword allows you to access variables, attributes, and methods of a defined class in python.

# %%
Question: What is Inheritance? Give an example for each type of inheritance.
Answer: Inheritance is a mechanism in which one class acquries the propety of another class. 
For example, a child inherits the traits of his/her parents.

Types of inheritance:
1) Single Inheritance : single inheritance allows a derivate class to inherit properties of one parent class, and this allows code reuse and the introduction of additional 
featues in existing code.
Example:
# python program for demondtrating single inheritance

# here, we will create the base class or the parent class
class parent1:
    def func_1(self):
        print("This function is defined inside the parent class")
# now, we will create the derived class
class child1(parent1):
    def func_2(self):
        print("this function is defined inside the child class")
# Driver's code
object= child1()
object.func_1()
object.func_2()

2) Multiple Inheritance: if a class is able to created from multiple base classes, this kind of inheritance is known as multiple inheritance. when there is multiple inheritance,
each of the attributes that are present in the classes of the base hs been passed on to the class that is derived from it.
Example:
# Here, we will create the base class 1
class Mother1:
    mothername1=""
    def mother1(self):
        print(self.mothername1)
        
#here, we will create the base class 2
class father1:
    fathername1= ""
    def father1(self):
        print(self.fathername1)

#now, we will create the derivative class
class son1(mother1, father1):
    def parents1(self):
        print("father name is:", self.fathername1)
        print("mother name is:", self.mothername1)
        
# Driver's code
s1 = son1()
s1.fathername1="Rajesh"
s1.mothername1= "sherya"
s1.parents 1()

3) multilevel inheritance, the features that are part of the original class, as well as the class that is derived from it, are passed on to the new class.
it is similar to a relationship involving grandparents and childern.
Example:
#Here, we will create the base class
class grandfather1:
    def__init__(self, grandfathername1):
        self.grandfathername1 = grandfathername1
        
#here, we will create the intermediate class
class father1(grandfather1):
    def__init__(self,fathername1,grandfathername1):
        self.fathername1 = fathername1
#here, we will create the derived class 
class son1(father1):
    def__init__(self, sonname1, fathername1, grandfathername1):
        self.sonname1 = sonname1
        
        #here, we will invoke the constructor of father class
        father1__init__(self,fathername1, granfdfathername1)
    def print_name(self):
        print('grandfather name is:', self.grandfathername1)
        print("father name is:",self.fathername1)
        print("son name is:",self.sonname 1)
#driver code
s1= son1('john','john jr',john jr jr')
print(s1.grandfathername1)
s1.print_name()
         
4) HIERARCHICAL INHERITANCE if multiple derived classes are created from the same base, this kind of inheritance is known as hierarchical inheritance. In this instance, we have two 
classes as a parent(base) clas as well as two children (derived) classes.

Example:
# Here, we will create the base class
class parent1:
    def func_1(self):
        print("This function is defined inside the parent class.")
# Derivied class2
class child_2(parent1):
    def func_3(self):
        print("this function is defined inside the child2")
# Driver's code
object1= child_1()
object2 = child_2()
object1.func_1()
object1.func_2()
object2.func_1()
